# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Important concepts

# %% [markdown]
# ## 1.1 Path

# %% [markdown]
# path is a location in the computer
# path can be described relatively or absolutely.
# Need to be careful when describing the path relatively as if the location of the folder changes, it might affect the relative path.

# %% [markdown]
# C:\\Users\Chammika\Desktop\data-01.txt

# %% [markdown]
# !cd .. # go up 2 files to the user file

# %% [markdown]
# ## 1.2 More about relative paths

# %% [markdown]
# .\data-files\data-01.txt      # the file data-01. txt in the folder data-files in the current folder

# %% [markdown]
# ..\data-files\data-01.txt     # the file data-0.1.txt in the folder data-files located in the folder above

# %% [markdown]
# ..\..\..\data-files\data-01.txt         # the file data-0.1.txt in the folder data-files located in the folder which is 3 folders above

# %% [markdown]
# ### macOS or Linux

# %% [markdown]
# ~\Desktop\data-01.txt

# %% [markdown]
# ## 1.3 Path separator

# %%
my_path= 'C:\\\\Users\\Cammika\\Desktop\\nata_01.txt' # For Windows, need to use // instead of / in order to distinguish a file path from code

# %%
print(my_path)
# Out:
# C:\\Users\Cammika\Desktop\nata_01.txt

# %% [markdown]
# windows: C:\\Users\chammika\Desktop\data-01.txt
#
# macOS: 	/Users/chammika/Desktop/data-01.txt
#
# if the code is to be shared and needs to work on both systems, do not hardcode with either path separator

# %% [markdown]
# ## 1.4 Text files vs. Binary files

# %% [markdown]
# Binary files: made up of '1' and '0' and need to know the format in order to extract the file
#
# Advantage of binary files: takes up less space
#
# Text file: made up of text

# %% [markdown]
# ## 1.5 Extensions

# %% [markdown]
# hahaha.ipynb        # .ipnyb is jupyter notebook extension

# %% [markdown]
# hahaha.xlsx          # .xlsx  is excel file extension

# %% [markdown]
# Extension tells us which software or app is used to extract details in a file

# %% [markdown]
# # 2 Opening and closing files

# %% [markdown]
# ## 2.1 Reading data

# %%
with open('spectrum-01.txt', 'r') as file:  # open spectrum-01.txt  to read only
    file_content = file.read()     # read the file

print(file_content)   # print the file
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %% [markdown]
# 'w': to write in the file
#
# 'rb': to read as binary file (for excel files)

# %%
file = open('spectrum-01.txt','r')  # Can also open the file to read only through this method but would need to manually close the file
data = file.read()
print(data)
file.close() # to close the file
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %% [markdown]
# ## 2.2 Writing data

# %%
text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'

# %% [markdown]
# ### Writing to a file in one go

# %%
with open('my-text-once.txt', 'w') as file:    # writes the text as one file 'my-text-once.txt' that is saved in the desktop
    file.write(text)

# %% [markdown]
# If this code runs again, the existing file will be overwritten

# %% [markdown]
# ### Writing to a file, line by line

# %%
with open('my-text-lines.txt', 'w') as file:  # writes the file line by line
    for line in text.splitlines():
        file.writelines(line)

# %%
text.splitlines()
# Out:
# ['Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.',
#  'Orbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.']

# %% [markdown]
# # 3 Some useful packages

# %%
import os # To access the OS to create, modify, delete and write code
import glob  # To search for files
import shutil # To copy files

# %% [markdown]
# # 4 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt') # To access 'data-01.txt' from the sub-directory 'sg-data' of the directory 'all-data'
print(path)
# Out:
# .\all-data\sg-data\data-01.txt

# %% [markdown]
# # 5 Folders

# %% [markdown]
# ## 5.1 Creating folders

# %%
os.mkdir('people') # create a folder 'people'

for person in ['John', 'Paul', 'Ringo']: # create files 'John','Paul','Ringo' in 'person' folder using a loop
    path = os.path.join('people', person) 
    print(f'Creating {path}')    # Dont need to include print() -  just to show what is happening
    os.mkdir(path) # To create files 'John','Paul','Ringo' into 'people' folder which is in person folder
# Out:
# Creating people\John
# Creating people\Paul
# Creating people\Ringo

# %% [markdown]
# ## 5.2 Checking for existence

# %% [markdown]
# ### Using try-except

# %%
for person in ['John', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:                        # To create files 'John','Paul','Ringo' into 'people' folder which is in person folder if the files are not created
        print(f'Creating {path}')
    except FileExistsError:    # If files John','Paul','Ringo' are present, skip creating the files and print message '{path} already exists;skipping creation' to notify user that files are already created
        print(f'{path} already exists; skipping creation.')
# Out:
# people\John already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %% [markdown]
# ### Using os.path.exists()

# %%
for person in ['John', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):            # If files John','Paul','Ringo' are already present,  print message '{path} already exists;skipping creation' to notify user that files are already created
        print(f'{path} already exists; skipping creation.')
    else:                              # Else, create files 'John','Paul','Ringo' into 'people' folder
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people\John already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %% [markdown]
# ## 5.3 Copying files

# %%
file_to_copy = 'sp2273_logo.png'
for person in ['John', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person) # To create path of each person file in the 'people' directory
    file_path = os.path.join(path_to_destination, file_to_copy) # To create path by joining the destination directory to 'sp2273_logo.png' file
    if os.path.exists(file_path):
        print(f'{file_path} already exists!')  # If file_path is present, print message 'file_path already exists'
    else:        
        shutil.copy('sp2273_logo.png', path_to_destination)  # Else, copy 'sp2273_logo.png' file to each person file in the 'people' directory
        print(f'Copied {file_to_copy} to {path_to_destination}')
# Out:
# Copied sp2273_logo.png to people\John
# Copied sp2273_logo.png to people\Paul
# Copied sp2273_logo.png to people\Ringo

# %%
file_to_copy='sp2273_logo.png'
for person in ['John', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs') 
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    # Move logo file
    current_path_of_logo = os.path.join('people', person, file_to_copy)
    new_path_of_logo = os.path.join('people', person, 'imgs', file_to_copy)

    shutil.move(current_path_of_logo, new_path_of_logo) # move file from current_path_of_logo to new_path_of logo
    print(f'Moved logo from {current_path_of_logo}to {new_path_of_logo}')
# Out:
# Moved logo from people\John\sp2273_logo.pngto people\John\imgs\sp2273_logo.png
# Moved logo from people\Paul\sp2273_logo.pngto people\Paul\imgs\sp2273_logo.png
# Moved logo from people\Ringo\sp2273_logo.pngto people\Ringo\imgs\sp2273_logo.png

# %% [markdown]
# # 6 Listing and looking for files

# %%
glob.glob('*') # To read and tell you all the files that are present in the current directory
# Out:
# ['files,_folders_&_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'people',
#  'SP2273 _ Working on Interdisciplinary Science, Pythonically - Files, Folders & OS (Need).html',
#  'SP2273 _ Working on Interdisciplinary Science, Pythonically - Files, Folders & OS (Need)_files',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
glob.glob('peo*') # To find and tell you the files in which their name contain 'peo' at the beginning
# Out:
# ['people']

# %%
glob.glob('peo*/*') # To tell you what is present in the folders that start with 'peo'
# Out:
# ['people\\John', 'people\\Paul', 'people\\Ringo']

# %%
glob.glob('people/**', recursive=True) # To tell you the sub-directories that are present in folders that start with 'peo'
# Out:
# ['people\\',
#  'people\\John',
#  'people\\John\\imgs',
#  'people\\John\\imgs\\sp2273_logo.png',
#  'people\\Paul',
#  'people\\Paul\\imgs',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo',
#  'people\\Ringo\\imgs',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %%
glob.glob('people/**/*.png', recursive=True) # To tell you the .png files that are in the people folder
# Out:
# ['people\\John\\imgs\\sp2273_logo.png',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %% [markdown]
# # 7 Extracting file info

# %%
path = 'people\\Ringo\\imgs\\sp2273_logo.png'
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1] # To split the extension from the rest 
name_only = filename.split('.')[0] # To split the filename from the rest (same as os.path.split(path))
print(filename, extension) # to print filename and extension
# Out:
# sp2273_logo.png png

# %%
os.path.split(path)      # Split filename from the rest
# Out:
# ('people\\Ringo\\imgs', 'sp2273_logo.png')

# %%
os.path.splitext(path)   # Split extension
# Out:
# ('people\\Ringo\\imgs\\sp2273_logo', '.png')

# %%
os.path.dirname(path)    # Show the directory
# Out:
# 'people\\Ringo\\imgs'

# %% [markdown]
# # 8 Deleting stuff

# %%
#os.remove('people/Ringo/imgs/sp2273_logo.png') # To remove a file

# %%
#os.rmdir('people/Ringo') # To remove empty directory

# %%
#shutil.rmtree('people/Ringo')  # To remove a directory with files
